# %%
import os

# %%
import pandas as pd

# %%
os.listdir()
# Out:
# ['.ipynb_checkpoints',
#  'Central',
#  'Central.docx',
#  'Central.zip',
#  'Eastern',
#  'Eastern.docx',
#  'Eastern.zip',
#  'Northern',
#  'Northern.docx',
#  'Northern.zip',
#  'North_Central',
#  'North_Central.docx',
#  'North_Central.zip',
#  'North_Western',
#  'North_Western.docx',
#  'North_Western.zip',
#  'Sabaragamuwa',
#  'Sabaragamuwa.docx',
#  'Sabaragamuwa.zip',
#  'Southern',
#  'Southern.docx',
#  'Southern.zip',
#  'Untitled.ipynb',
#  'Uva',
#  'Uva.docx',
#  'Uva.zip',
#  'Western',
#  'Western.docx',
#  'Western.zip']

# %%
csv_files = []
for root, dirs, files in os.walk('.'):
    for file in files:
        if file.endswith('.csv'):
            csv_files.append(os.path.join(root, file))

# %%
csv_files
# Out:
# ['.\\Central\\Central.csv',
#  '.\\Eastern\\Assessing Knowledge, Attitude and Practices Among Students on E-Learning Platforms.csv',
#  '.\\Northern\\Assessing Knowledge, Attitude and Practices Among Students on E-Learning Platforms.csv',
#  '.\\North_Central\\Assessing Knowledge, Attitude and Practices Among Students on E-Learning Platforms.csv',
#  '.\\North_Western\\North_Western.csv',
#  '.\\Sabaragamuwa\\Sabaragamuwa.csv',
#  '.\\Southern\\Southern.csv',
#  '.\\Uva\\Assessing Knowledge, Attitude and Practices Among Students on E-Learning Platforms.csv',
#  '.\\Western\\Western.csv']

# %%
len(csv_files)
# Out:
# 9

# %%
df_dict = {}
for file in csv_files:
    province = file.split('\\')[1]
    df_dict[province] = pd.read_csv(file)

# %%
df_dict['Western']
# Out:
#                           Timestamp  \
# 0    2021/10/19 5:50:26 pm GMT+5:30
# 1    2021/10/19 5:55:04 pm GMT+5:30
# 2   2021/10/20 10:16:10 am GMT+5:30
# 3   2021/10/20 10:18:52 am GMT+5:30
# 4   2021/10/20 10:21:03 am GMT+5:30
# 5    2021/10/20 1:37:45 pm GMT+5:30
# 6    2021/10/20 1:44:23 pm GMT+5:30
# 7    2021/10/20 1:46:21 pm GMT+5:30
# 8    2021/10/20 5:26:42 pm GMT+5:30
# 9    2021/10/20 5:29:53 pm GMT+5:30
# 10   2021/10/20 5:32:39 pm GMT+5:30
# 11   2021/10/20 5:40:40 pm GMT+5:30
# 12   2021/10/20 5:42:08 pm GMT+5:30
# 13   2021/10/20 5:46:18 pm GMT+5:30
# 14   2021/10/20 5:48:56 pm GMT+5:30
#
#    Do you wish to participate in this questionnaire?   \
# 0                                                 Yes
# 1                                                 Yes
# 2                                                 Yes
# 3                                                 Yes
# 4                                                 Yes
# ...

# %%
master_df = pd.concat(list(df_dict.values()))

# %%
master_df.shape
# Out:
# (100, 20)

# %%
master_df.to_csv('master_dataset.csv', index=False)

# %%
master_df = master_df.sample(frac=1).reset_index(drop=True)

# %%
master_df.drop(columns=['Timestamp'], inplace=True)

# %%
master_df
# Out:
#    Do you wish to participate in this questionnaire?   \
# 0                                                 Yes
# 1                                                 Yes
# 2                                                 Yes
# 3                                                 Yes
# 4                                                 Yes
# ..                                                ...
# 95                                                Yes
# 96                                                Yes
# 97                                                Yes
# 98                                                Yes
# 99                                                Yes
#
#    Please select your age category  Please select your gender  \
# 0                 Between 21 and 25                      Male
# 1                           Over 25                      Male
# 2                 Between 21 and 25                      Male
# 3                           Over 25                      Male
# ...

# %%
df = pd.read_csv('master_dataset.csv')

# %%
df
# Out:
#                   Age  Gender                Province           Institution  \
# 0   Between 21 and 25    Male       Southern Province  Government Institute
# 1             Over 25    Male       Southern Province  Government Institute
# 2   Between 21 and 25    Male  North Western Province  Government Institute
# 3             Over 25    Male  North Central Province  Government Institute
# 4   Between 21 and 25    Male        Eastern Province  Government Institute
# ..                ...     ...                     ...                   ...
# 95  Between 21 and 25  Female       Southern Province  Government Institute
# 96  Between 21 and 25    Male        Eastern Province  Government Institute
# 97            Over 25  Female        Western Province  Government Institute
# 98  Between 21 and 25    Male        Central Province  Government Institute
# 99  Between 21 and 25    Male        Western Province  Government Institute
#
# ...

# %%
df.loc[0]
# Out:
# Do you wish to participate in this questionnaire?                                                                                                                                Yes
# Please select your age category                                                                                                                                    Between 21 and 25
# Please select your gender                                                                                                                                                       Male
# Please select your province of residence                                                                                                                           Southern Province
# Please select the type of your educational institute                                                                                                            Government Institute
# ...

# %%
df.loc[0]["Please select your age category"]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2894             try:
# -> 2895                 return self._engine.get_loc(casted_key)
#    2896             except KeyError as err:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Please select your age category'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-6-a92df1d439e1> in <module>
# ...

# %%
df['Age'].unique()
# Out:
# array(['Between 21 and 25', 'Over 25', 'Under 20'], dtype=object)

# %%
df['Age'].replace('Between 21 and 25', 'mid', inplace=True)

# %%
df.Gender.replace('Female', 1, inplace=True)

# %%
df.Institution.unique()
# Out:
# array(['government', 'private', 'foreign'], dtype=object)

# %%
df.Institution.replace('Foreign Institute', 'foreign', inplace=True)

# %%
df.Expenses.unique()
# Out:
# array(['Educational expenses fully/partially covered by a scholarship',
#        'Provided by family',
#        'Provided by family;Educational expenses fully/partially covered by a scholarship',
#        'I have a part-time/full-time job (I have a source of income);Provided by family',
#        'I have a part-time/full-time job (I have a source of income)',
#        'I have a part-time/full-time job (I have a source of income);Educational expenses fully/partially covered by a scholarship',
#        'I have a part-time/full-time job (I have a source of income);Provided by family;Educational expenses fully/partially covered by a scholarship'],
#       dtype=object)

# %%
df.to_csv('prepared_df.csv', index=False)

# %%
df.columns
# Out:
# Index(['Age', 'Gender', 'Province', 'Institution', 'Expenses',
#        'Extracurricular', 'same_province', 'knowledge', 'technical_knowledge',
#        'comfortable', 'comfy_issues', 'preferred', 'likes', 'dislikes',
#        'continuation', 'notes', 'beyond_learning', 'daily_usage'],
#       dtype='object')

# %%
exp_str1 = 'Educational expenses fully/partially covered by a scholarship'
exp_str2 = 'Provided by family'
exp_str3 = 'I have a part-time/full-time job (I have a source of income)'
capable_family = [0] * 100
for i, item in enumerate(df.Expenses.tolist()):
    for sub_item in item.split(';'):
        if sub_item == exp_str2:
            capable_family[i] = 1
            break

# %%
df['expenses_score'] = expenses_score
df['capable_family'] = capable_family

# %%
df
# Out:
#      Age  Gender                Province Institution  \
# 0    mid       0       Southern Province  government
# 1   high       0       Southern Province  government
# 2    mid       0  North Western Province  government
# 3   high       0  North Central Province  government
# 4    mid       0        Eastern Province  government
# ..   ...     ...                     ...         ...
# 95   mid       1       Southern Province  government
# 96   mid       0        Eastern Province  government
# 97  high       1        Western Province  government
# 98   mid       0        Central Province  government
# 99   mid       0        Western Province  government
#
#                                              Expenses Extracurricular  \
# 0   Educational expenses fully/partially covered b...              No
# 1                                  Provided by family             Yes
# 2   Provided by family;Educational expenses fully/...             Yes
# ...

# %%
df.drop('Expenses', axis=1, inplace=True)

# %%
df
# Out:
#      Age  Gender                Province Institution Extracurricular  \
# 0    mid       0       Southern Province  government              No
# 1   high       0       Southern Province  government             Yes
# 2    mid       0  North Western Province  government             Yes
# 3   high       0  North Central Province  government             Yes
# 4    mid       0        Eastern Province  government             Yes
# ..   ...     ...                     ...         ...             ...
# 95   mid       1       Southern Province  government             Yes
# 96   mid       0        Eastern Province  government              No
# 97  high       1        Western Province  government             Yes
# 98   mid       0        Central Province  government             Yes
# 99   mid       0        Western Province  government             Yes
#
#               same_province  \
# 0   In a different province
# 1   In a different province
# 2   In a different province
# ...

# %%
df.Extracurricular.replace('No', 0, inplace=True)

# %%
df
# Out:
#      Age  Gender                Province Institution  Extracurricular  \
# 0    mid       0       Southern Province  government                0
# 1   high       0       Southern Province  government                1
# 2    mid       0  North Western Province  government                1
# 3   high       0  North Central Province  government                1
# 4    mid       0        Eastern Province  government                1
# ..   ...     ...                     ...         ...              ...
# 95   mid       1       Southern Province  government                1
# 96   mid       0        Eastern Province  government                0
# 97  high       1        Western Province  government                1
# 98   mid       0        Central Province  government                1
# 99   mid       0        Western Province  government                1
#
#               same_province  \
# 0   In a different province
# 1   In a different province
# 2   In a different province
# ...

# %%
df.same_province.unique()
# Out:
# array(['In a different province', 'In my own province',
#        'In a different country'], dtype=object)

# %%
same_province = [0] * 100
for i, item in enumerate(df.same_province.tolist()):
    if item == 'In my own province':
        same_province[i] = 1

# %%
df['same_province'] = same_province

# %%
df
# Out:
#      Age  Gender                Province Institution  Extracurricular  \
# 0    mid       0       Southern Province  government                0
# 1   high       0       Southern Province  government                1
# 2    mid       0  North Western Province  government                1
# 3   high       0  North Central Province  government                1
# 4    mid       0        Eastern Province  government                1
# ..   ...     ...                     ...         ...              ...
# 95   mid       1       Southern Province  government                1
# 96   mid       0        Eastern Province  government                0
# 97  high       1        Western Province  government                1
# 98   mid       0        Central Province  government                1
# 99   mid       0        Western Province  government                1
#
#     same_province                                          knowledge  \
# ...

# %%
df
# Out:
#      Age  Gender                Province Institution  Extracurricular  \
# 0    mid       0       Southern Province  government                0
# 1   high       0       Southern Province  government                1
# 2    mid       0  North Western Province  government                1
# 3   high       0  North Central Province  government                1
# 4    mid       0        Eastern Province  government                1
# ..   ...     ...                     ...         ...              ...
# 95   mid       1       Southern Province  government                1
# 96   mid       0        Eastern Province  government                0
# 97  high       1        Western Province  government                1
# 98   mid       0        Central Province  government                1
# 99   mid       0        Western Province  government                1
#
#     same_province                                          knowledge  \
# ...

# %%
df.knowledge.unique()
# Out:
# array(['I learned through e-learning platforms for the first time during undergraduate studies and I didn’t know about e-learning platforms before that',
#        'I have learned through e-learning platforms even before undergraduate studies',
#        'I learned through e-learning platforms for the first time during undergraduate studies, but I knew about e-learning platforms before that'],
#       dtype=object)

# %%
know_str1 = 'I learned through e-learning platforms for the first time during undergraduate studies and I didn’t know about e-learning platforms before that'
know_str2 = 'I have learned through e-learning platforms even before undergraduate studies'
know_str3 = 'I learned through e-learning platforms for the first time during undergraduate studies, but I knew about e-learning platforms before that'

knowledge = []
for item in df.knowledge.tolist():
    if item == know_str1:
        knowledge.append(10)
    elif item == know_str2:
        knowledge.append(20)
    elif item == know_str3:
        knowledge.append(30)
    else:
        print('isuse')

# %%
df['knowledge'] = knowledge

# %%
df
# Out:
#      Age  Gender                Province Institution  Extracurricular  \
# 0    mid       0       Southern Province  government                0
# 1   high       0       Southern Province  government                1
# 2    mid       0  North Western Province  government                1
# 3   high       0  North Central Province  government                1
# 4    mid       0        Eastern Province  government                1
# ..   ...     ...                     ...         ...              ...
# 95   mid       1       Southern Province  government                1
# 96   mid       0        Eastern Province  government                0
# 97  high       1        Western Province  government                1
# 98   mid       0        Central Province  government                1
# 99   mid       0        Western Province  government                1
#
#     same_province  knowledge  \
# 0               0         10
# 1               0         20
# 2               0         30
# ...

# %%
df
# Out:
#      Age  Gender                Province Institution  Extracurricular  \
# 0    mid       0       Southern Province  government                0
# 1   high       0       Southern Province  government                1
# 2    mid       0  North Western Province  government                1
# 3   high       0  North Central Province  government                1
# 4    mid       0        Eastern Province  government                1
# ..   ...     ...                     ...         ...              ...
# 95   mid       1       Southern Province  government                1
# 96   mid       0        Eastern Province  government                0
# 97  high       1        Western Province  government                1
# 98   mid       0        Central Province  government                1
# 99   mid       0        Western Province  government                1
#
#     same_province  knowledge  \
# 0               0         10
# 1               0         20
# 2               0         30
# ...

# %%
df.technical_knowledge.unique()
# Out:
# array(['I can resolve common technical issues, if it’s not something usual I seek assistance',
#        'I can resolve any technical issue if it’s from my side',
#        'I seek assistance from someone for any technical issue'],
#       dtype=object)

# %%
tk_strs = {'I can resolve common technical issues, if it’s not something usual I seek assistance': 20,
           'I can resolve any technical issue if it’s from my side': 10,
           'I seek assistance from someone for any technical issue': 0}

technical_knowledge = []
for item in df.technical_knowledge.tolist():
    technical_knowledge.append(tk_strs[item])
df['technical_knowledge'] = technical_knowledge

# %%
df
# Out:
#      Age  Gender                Province Institution  Extracurricular  \
# 0    mid       0       Southern Province  government                0
# 1   high       0       Southern Province  government                1
# 2    mid       0  North Western Province  government                1
# 3   high       0  North Central Province  government                1
# 4    mid       0        Eastern Province  government                1
# ..   ...     ...                     ...         ...              ...
# 95   mid       1       Southern Province  government                1
# 96   mid       0        Eastern Province  government                0
# 97  high       1        Western Province  government                1
# 98   mid       0        Central Province  government                1
# 99   mid       0        Western Province  government                1
#
#     same_province  knowledge  technical_knowledge comfortable  \
# 0               0         10                   20          No
# ...

# %%
df.comfortable.replace('No', 0, inplace=True)

# %%
df
# Out:
#      Age  Gender                Province Institution  Extracurricular  \
# 0    mid       0       Southern Province  government                0
# 1   high       0       Southern Province  government                1
# 2    mid       0  North Western Province  government                1
# 3   high       0  North Central Province  government                1
# 4    mid       0        Eastern Province  government                1
# ..   ...     ...                     ...         ...              ...
# 95   mid       1       Southern Province  government                1
# 96   mid       0        Eastern Province  government                0
# 97  high       1        Western Province  government                1
# 98   mid       0        Central Province  government                1
# 99   mid       0        Western Province  government                1
#
#     same_province  knowledge  technical_knowledge  comfortable  \
# ...

# %%
df.comfy_issues.unique()
# Out:
# array(['It takes me some time to find how to unmute or turn on video;I get panicked as I am not prepared',
#        'I get panicked as I am not prepared', 'Not Applicable',
#        'I am not comfortable unmuting me or turning on my video',
#        'I am not comfortable unmuting me or turning on my video;It takes me some time to find how to unmute or turn on video',
#        'I am not comfortable unmuting me or turning on my video;I get panicked as I am not prepared',
#        'It takes me some time to find how to unmute or turn on video'],
#       dtype=object)

# %%
comf_strs = {
    'It takes me some time to find how to unmute or turn on video': 10,
    'I get panicked as I am not prepared': 5,
    'I am not comfortable unmuting me or turning on my video': 8,
    'Not Applicable': 0
}
comfy_issues = [0] * 100
for i, item in enumerate(df.comfy_issues.tolist()):
    for sub_item in item.split(';'):
        comfy_issues[i] += comf_strs[sub_item]

# %%
df['comfy_issues'] = comfy_issues

# %%
df
# Out:
#      Age  Gender                Province Institution  Extracurricular  \
# 0    mid       0       Southern Province  government                0
# 1   high       0       Southern Province  government                1
# 2    mid       0  North Western Province  government                1
# 3   high       0  North Central Province  government                1
# 4    mid       0        Eastern Province  government                1
# ..   ...     ...                     ...         ...              ...
# 95   mid       1       Southern Province  government                1
# 96   mid       0        Eastern Province  government                0
# 97  high       1        Western Province  government                1
# 98   mid       0        Central Province  government                1
# 99   mid       0        Western Province  government                1
#
#     same_province  knowledge  technical_knowledge  comfortable  comfy_issues  \
# ...

# %%
preferred = [0] * 100
for i, item in enumerate(df.preferred.tolist()):
    if item == 'Yes':
        preferred[i] = 1
    elif item == 'No':
        preferred[i] = -1

df['preferred'] = preferred

# %%
df
# Out:
#      Age  Gender                Province Institution  Extracurricular  \
# 0    mid       0       Southern Province  government                0
# 1   high       0       Southern Province  government                1
# 2    mid       0  North Western Province  government                1
# 3   high       0  North Central Province  government                1
# 4    mid       0        Eastern Province  government                1
# ..   ...     ...                     ...         ...              ...
# 95   mid       1       Southern Province  government                1
# 96   mid       0        Eastern Province  government                0
# 97  high       1        Western Province  government                1
# 98   mid       0        Central Province  government                1
# 99   mid       0        Western Province  government                1
#
#     same_province  knowledge  technical_knowledge  comfortable  comfy_issues  \
# ...

# %%
df.columns
# Out:
# Index(['Age', 'Gender', 'Province', 'Institution', 'Extracurricular',
#        'same_province', 'knowledge', 'technical_knowledge', 'comfortable',
#        'comfy_issues', 'preferred', 'likes', 'dislikes', 'continuation',
#        'notes', 'beyond_learning', 'daily_usage', 'expenses_score',
#        'capable_family'],
#       dtype='object')

# %%
dislikes = []
for item in df.dislikes.tolist():
    dislikes.append(len(item.split(';')) - 1)
df['dislikes'] = dislikes

# %%
df.drop('continuation', axis=1, inplace=True)

# %%
df.notes.unique()
# Out:
# array(['No, but I was used to take notes in in-class lectures',
#        'No, I didn’t even take notes in in-class lectures', 'Maybe',
#        'Yes'], dtype=object)

# %%
notes_str = {
    'No, but I was used to take notes in in-class lectures': -2,
    'No, I didn’t even take notes in in-class lectures': -1,
    'Maybe': 0,
    'Yes': 1
}

notes = []
for item in df.notes.tolist():
    notes.append(notes_str[item])
    
df['notes'] = notes

# %%
df
# Out:
#      Age  Gender                Province Institution  Extracurricular  \
# 0    mid       0       Southern Province  government                0
# 1   high       0       Southern Province  government                1
# 2    mid       0  North Western Province  government                1
# 3   high       0  North Central Province  government                1
# 4    mid       0        Eastern Province  government                1
# ..   ...     ...                     ...         ...              ...
# 95   mid       1       Southern Province  government                1
# 96   mid       0        Eastern Province  government                0
# 97  high       1        Western Province  government                1
# 98   mid       0        Central Province  government                1
# 99   mid       0        Western Province  government                1
#
#     same_province  knowledge  technical_knowledge  comfortable  comfy_issues  \
# ...

# %%
df.daily_usage.replace('No', 0, inplace=True)

# %%
df
# Out:
#      Age  Gender                Province Institution  Extracurricular  \
# 0    mid       0       Southern Province  government                0
# 1   high       0       Southern Province  government                1
# 2    mid       0  North Western Province  government                1
# 3   high       0  North Central Province  government                1
# 4    mid       0        Eastern Province  government                1
# ..   ...     ...                     ...         ...              ...
# 95   mid       1       Southern Province  government                1
# 96   mid       0        Eastern Province  government                0
# 97  high       1        Western Province  government                1
# 98   mid       0        Central Province  government                1
# 99   mid       0        Western Province  government                1
#
#     same_province  knowledge  technical_knowledge  comfortable  comfy_issues  \
# ...

# %%
df_temp = pd.read_csv('master_dataset.csv')

# %%
df['daily_usage'] = df_temp['daily_usage']

# %%
df
# Out:
#      Age  Gender                Province Institution  Extracurricular  \
# 0    mid       0       Southern Province  government                0
# 1   high       0       Southern Province  government                1
# 2    mid       0  North Western Province  government                1
# 3   high       0  North Central Province  government                1
# 4    mid       0        Eastern Province  government                1
# ..   ...     ...                     ...         ...              ...
# 95   mid       1       Southern Province  government                1
# 96   mid       0        Eastern Province  government                0
# 97  high       1        Western Province  government                1
# 98   mid       0        Central Province  government                1
# 99   mid       0        Western Province  government                1
#
#     same_province  knowledge  technical_knowledge  comfortable  comfy_issues  \
# ...

# %%
df.to_csv('master_processed_data.csv', index=False)

# %%
df[df['Gender'] == 0].shape
# Out:
# (64, 18)

# %%
dfB = df[df['same_province'] == 1]

# %%
dfB[dfB['preferred']==1].shape
# Out:
# (11, 18)
